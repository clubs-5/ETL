# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
pf = pd.read_csv('Prime.csv')
# 字體大寫
pf = pf.rename(columns = str.title )
pf
# Out:
#                                    Award_Title        Years  \
# 0                     Outstanding Drama Series  2020 Awards
# 1                     Outstanding Drama Series  2020 Awards
# 2                     Outstanding Drama Series  2020 Awards
# 3                     Outstanding Drama Series  2020 Awards
# 4                     Outstanding Drama Series  2020 Awards
# ...                                        ...          ...
# 22650  Most Outstanding Television Personality  1949 Awards
# 22651  Most Outstanding Television Personality  1949 Awards
# 22652          Most Popular Television Program  1949 Awards
# 22653          Most Popular Television Program  1949 Awards
# 22654          Most Popular Television Program  1949 Awards
#
#                  Finalist  Winner  \
# 0              Succession  Winner
# 1        Better Call Saul     NaN
# 2             Killing Eve     NaN
# 3                   Ozark     NaN
# 4         Stranger Things     NaN
# ...

# %%
# 將years Award字串取代
pf['Years'] = pf['Years'].str.split(' ').str.get(0)

# %%
# 將groups 分出 producer
pf['producer'] = pf['Groups'].str.split(',').str.get(0)

# %%
pf['producer_2'] = pf['Groups'].str.split(',').str.get(4)

# %%
# 刪除 入圍者為 na 項目
pf['Finalist'] = pf['Finalist'].dropna()

# %%
# 將winner 取代為1 沒得獎為0
pf['Winner'] = pf['Winner'].replace(np.nan,0)
pf['Winner'] = pf['Winner'].replace('Winner',1)

# %%
# 算出col 幾項
all_title = []
for x in pf.Award_Title:
    all_title.append(x)
title = pd.unique(all_title)
a = title.tolist()
print(type(a))
# Out:
# <class 'list'>

# %%
missing_values_count = pf.isnull().sum()
missing_values_count[0:10]
# Out:
# Award_Title       83
# Years              0
# Finalist         154
# Winner             0
# Groups          1115
# producer        1115
# producer_2     13237
# dtype: int64

# %%
total_cells = np.product(pf.shape)
total_missing = missing_values_count.sum()

percent_missing = (total_missing / total_cells )   *100
print(percent_missing)
# Out:
# 9.902575905665731

# %%
# 資料清洗 groups
o = 0
while o < len(pf):
    word = ''
    for i in str(pf['Groups'][o]).split(',,'):
        if i != '':
            word += i.lstrip(' ,').split(',')[0] + ','
            pf.loc[o,'Groups'] = word.rstrip(',')
    print(o)
    o += 1
# Out:
# 1
# 19322
# 19323
# 19324
# 19325
# 19326
# 19327
# 19328
# 19329
# 19330
# 19331
# 19332
# 19333
# 19334
# 19335
# 19336
# 19337
# 19338
# 19339
# 19340
# 19341
# 19342
# 19343
# 19344
# 19345
# 19346
# 19347
# 19348
# 19349
# 19350
# 19351
# 19352
# 19353
# 19354
# 19355
# 19356
# 19357
# 19358
# 19359
# 19360
# 19361
# 19362
# 19363
# 19364
# 19365
# 19366
# 19367
# 19368
# 19369
# 19370
# 19371
# 19372
# 19373
# 19374
# 19375
# 19376
# 19377
# 19378
# 19379
# 19380
# 19381
# 19382
# 19383
# 19384
# 19385
# 19386
# 19387
# 19388
# 19389
# 19390
# 19391
# 19392
# 19393
# 19394
# 19395
# 19396
# 19397
# 19398
# 19399
# 19400
# 19401
# 19402
# 19403
# 19404
# 19405
# 19406
# 19407
# 19408
# 19409
# 19410
# 19411
# 19412
# 19413
# 19414
# 19415
# 19416
# 19417
# 19418
# 19419
# 19420
# 19421
# 19422
# 19423
# 19424
# 19425
# 19426
# 19427
# 19428
# 19429
# 19430
# 19431
# 19432
# 19433
# 19434
# 19435
# 19436
# 19437
# 19438
# 19439
# 19440
# 19441
# 19442
# 19443
# 19444
# 19445
# ...

# %%
pf
# Out:
#                                    Award_Title Years            Finalist  \
# 0                     Outstanding Drama Series  2020          Succession
# 1                     Outstanding Drama Series  2020    Better Call Saul
# 2                     Outstanding Drama Series  2020         Killing Eve
# 3                     Outstanding Drama Series  2020               Ozark
# 4                     Outstanding Drama Series  2020     Stranger Things
# ...                                        ...   ...                 ...
# 22650  Most Outstanding Television Personality  1949    Patricia Morison
# 22651  Most Outstanding Television Personality  1949         Rita La Roy
# 22652          Most Popular Television Program  1949     Stump the Stars
# 22653          Most Popular Television Program  1949  Armchair Detective
# 22654          Most Popular Television Program  1949      Judy Splinters
#
#        Winner                                             Groups  \
# ...

# %%
pf['Years'] = pf['Years'].astype(str).astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-155-5a4ffe85fe44> in <module>
# ----> 1 pf['Years'] = pf['Years'].astype(str).astype(int)
#
# ~/.local/share/virtualenvs/prime_data_cleaning-7Zb4F0vR/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~/.local/share/virtualenvs/prime_data_cleaning-7Zb4F0vR/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# ...

# %%
pf.iloc[:,7:] = pf.iloc[:,7:].astype('string')

# %%
# 將 winner 成為類別型
pf['Winner'] = pf['Winner'].astype('string')

# %%
# 算出不重複項得獎項 years = 2020
years_2020 = pf[pf['Years'] >=2020]
all_title = []
for x in years_2020.Award_Title:
    all_title.append(x)
title = pd.unique(all_title)
len(title)

# %%
# filter years 2000 <= x <=2020 找出這二十年來固定獎項
filter1  = (pf['Years'] <=  2020 )
filter2 =  (pf['Years'] >=  2000)
years  =  pf[filter1 & filter2]

# %%
pf

# %%
all_title = []
for x in years.Award_Title:
    all_title.append(x)
title = pd.unique(all_title)
len(title)

# %%
# 找出符合total
#filter_2020 = (pf['Years'] >=2020)
#years_2020 = pf[filter_2020]
awards = pd.get_dummies(pf.Award_Title)
pf = pd.concat([pf,awards],axis=1)
pf
# Out:
#                                    Award_Title Years            Finalist  \
# 0                     Outstanding Drama Series  2020          Succession
# 1                     Outstanding Drama Series  2020    Better Call Saul
# 2                     Outstanding Drama Series  2020         Killing Eve
# 3                     Outstanding Drama Series  2020               Ozark
# 4                     Outstanding Drama Series  2020     Stranger Things
# ...                                        ...   ...                 ...
# 22650  Most Outstanding Television Personality  1949    Patricia Morison
# 22651  Most Outstanding Television Personality  1949         Rita La Roy
# 22652          Most Popular Television Program  1949     Stump the Stars
# 22653          Most Popular Television Program  1949  Armchair Detective
# 22654          Most Popular Television Program  1949      Judy Splinters
#
#       Winner                                             Groups  \
# ...

# %%
# 設計出當後面獎項有winner 變成 2 代表得獎
for i,j in pf.iterrows():
    for jb in j:
        print(jb)
    # if j['Winner'] == '1':
    #     j[7:].replace("1","2")
    #     print(j)

# %%
for i,j in pf.iterrows():
    print(j[7:] =='2')

# %%
''' 以得獎者與得獎影集做區分 假如說得獎者為人 group 會是影集名稱  假如是影集會是 製作團隊
    現在要將得獎者為人的title 換成影集'''

# %%
pf['Finalist']
# Out:
# 0                Succession
# 1          Better Call Saul
# 2               Killing Eve
# 3                     Ozark
# 4           Stranger Things
#                 ...
# 22650      Patricia Morison
# 22651           Rita La Roy
# 22652       Stump the Stars
# 22653    Armchair Detective
# 22654        Judy Splinters
# Name: Finalist, Length: 22655, dtype: object

# %%
# 列出最常出現前10名
title_counts = pf['Award_Title'].value_counts()
title_counts[:10]
# Out:
# Outstanding Comedy Series                            284
# Outstanding Drama Series                             253
# Outstanding Lead Actress in a Comedy Series          247
# Outstanding Lead Actor in a Comedy Series            244
# Outstanding Lead Actress in a Drama Series           243
# Outstanding Lead Actor in a Drama Series             243
# Outstanding Supporting Actor in a Drama Series       228
# Outstanding Supporting Actress in a Drama Series     224
# Outstanding Supporting Actress in a Comedy Series    210
# Outstanding Children's Program                       209
# Name: Award_Title, dtype: int64

# %%
# 將前20名最多入圍獎列出
subset = title_counts[:20]
sns.barplot(y = subset.index , x = subset.values)
# Out:
# <AxesSubplot:>

# %%
pf
# Out:
#                                    Award_Title Years            Finalist  \
# 0                     Outstanding Drama Series  2020          Succession
# 1                     Outstanding Drama Series  2020    Better Call Saul
# 2                     Outstanding Drama Series  2020         Killing Eve
# 3                     Outstanding Drama Series  2020               Ozark
# 4                     Outstanding Drama Series  2020     Stranger Things
# ...                                        ...   ...                 ...
# 22650  Most Outstanding Television Personality  1949    Patricia Morison
# 22651  Most Outstanding Television Personality  1949         Rita La Roy
# 22652          Most Popular Television Program  1949     Stump the Stars
# 22653          Most Popular Television Program  1949  Armchair Detective
# 22654          Most Popular Television Program  1949      Judy Splinters
#
#       Winner                                             Groups  \
# ...
